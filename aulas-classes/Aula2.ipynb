# %%
'''
Código para verificar a versão do python
'''
# !python -V
# Out:
# Python 3.11.12

# %%
'''
operações
'''
#adição
print (4+4)

#subtração
print (5-3)

#multiplicação
print (5 * 3)

#divisão
print (20 / 5)

#potência
print (3**3) #ou
print (pow(3,3))

#módulo/ resto da divisão
print (20 % 2)

#arredondar
print (round(10.23735, 3))
# Out:
# 8
# 2
# 15
# 4.0
# 27
# 27
# 0
# 10.237

# %%
#tipos de dados

print (type(5))
print (type(10.0))
print (type('Python'))
print (type('w'))
print (type(True))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'str'>
# <class 'bool'>

# %%
#Variáveis

velocidade = 10
tempo = 5

print(velocidade)

print(tempo)


#sem variáveis
print ( 10*5)

#com variáveis
velocidade = 10
tempo = 5
distancia = velocidade * tempo
print(distancia)

resultado = velocidade*10
print (resultado)


# ordem de operações padrão da matemática
velocidade + (4*resultado) - distancia
# Out:
# 10
# 5
# 50
# 50
# 100
# 360

# %%
# Exemplo de tipagem dinâmica
x= 10 # x é um inteiro (int)
print(x)
print(type(x))

x = 'hello' # x agora é uma string
print (x)
print(type(x))
# Out:
# 10
# <class 'int'>
# hello
# <class 'str'>

# %% [markdown]
# variáveis criadas com letra maisucula são consideradas uma constante

# %%
cidade1, cidade2, cidade3 = 'São Paulo', 'Rio de Janeiro' , 'Belo Horizonte'
print(cidade1)
print(cidade2)
print(cidade3)
# Out:
# São Paulo
# Rio de Janeiro
# Belo Horizonte

# %%
primeiro_nome= 'Gustavo'
segundo_nome= 'Alves'
terceiro_nome = 'da Costa Lima'

nome_completo = primeiro_nome + ' ' + segundo_nome + ' ' + terceiro_nome
print(nome_completo)
print(type(nome_completo))
# Out:
# Gustavo Alves da Costa Lima
# <class 'str'>

# %%
a = 10
b = 20
soma = a+b
print(soma)
# Out:
# 30

# %%
celsius = 25
fahrenheit = (celsius*9/5)+32
print('A temperatura de ' +  str(celsius) + ' graus Celsius é igual a ' + str(fahrenheit) + ' graus fahrenheit')
# Out:
# A temperatura de 25 graus Celsius é igual a 77.0 graus fahrenheit

# %%
salario_bruto = 3000
INSS = 3000 * 0.08
salario_liquido = salario_bruto - INSS
print ('Salário bruto:' +  " R$" + str(salario_bruto) + "\nDesconto INSS:" + 'R$' + str(INSS) + '\nSalário líquido:' + 'R$' + str(salario_liquido,
                                                                                                                                  ))
# Out:
# Salário bruto: R$3000
# Desconto INSS:R$240.0
# Salário líquido:R$2760.0
